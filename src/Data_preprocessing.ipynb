# %% [markdown]
# ### Importing Libraries

# %%
import os
import geopandas as gpd
from PIL import Image, ImageDraw
import numpy as np
Image.MAX_IMAGE_PIXELS = None
# from osgeo import gdal
from shapely.geometry import shape, box
import fiona
import rasterio
from rasterio.windows import Window

# %% [markdown]
# ### Cutting Tif files into 1024x1024 sized tif files

# %%
def is_tile_empty(data):
    # Check if the tile contains any data (non-zero values)
    try:
        return np.all(data[3] == 0)
    except Exception as e:
        return True

# %%
def split_tiff(input_path, output_folder, tile_size):
    try:
        with rasterio.open(input_path) as src:
            width, height = src.width, src.height
            num_tiles_x = (width + tile_size - 1) // tile_size
            num_tiles_y = (height + tile_size - 1) // tile_size

            for tile_y in range(num_tiles_y):
                for tile_x in range(num_tiles_x):
                    left = tile_x * tile_size
                    upper = tile_y * tile_size
                    right = min(left + tile_size, width)
                    lower = min(upper + tile_size, height)

                    window = Window(left, upper, right - left, lower - upper)
                    transform = src.window_transform(window)

                    # Read the data within the window and create a new cropped raster
                    data = src.read(window=window)
                    profile = src.profile.copy()
                    profile.update(width=right - left, height=lower - upper, transform=transform)
                    
                    if is_tile_empty(data):
                        # Skip saving the file if it's empty
                        continue

                    # Extract the original file name without extension
                    file_name = os.path.splitext(os.path.basename(input_path))[0]

                    # Save the cropped raster with metadata
                    tile_path = os.path.join(output_folder, f"{file_name}_{tile_x}_{tile_y}.tif")
                    with rasterio.open(tile_path, 'w', **profile) as dst:
                        dst.write(data)
    except Exception as e:
        print(f"Error processing '{input_path}': {e}")

# %%
def crop_directory(directory_path, output_path, tile_size):

    for location_folder in os.listdir(directory_path):
        location_folder_path = os.path.join(directory_path, location_folder)

        geotiff_folder_path = os.path.join(location_folder_path, "Geotiff")

        output_subfolder = os.path.join("Cropped_Tif_File", location_folder)
        output_folder = os.path.join(output_path, output_subfolder)
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)
        else:
            continue
        
        if not os.path.exists(geotiff_folder_path):
            print("path does not exists", geotiff_folder_path)
            continue

        for file in os.listdir(geotiff_folder_path):
            if file.endswith(".tif") or file.endswith(".tiff"):
                input_file = os.path.join(geotiff_folder_path, file)
                split_tiff(input_file, output_folder, tile_size)

# %%
home_directory = "Orthos, DSMs & Shapefiles"
output_directory = "Dataset"
tile_size = 1024

crop_directory(home_directory, output_directory, tile_size)

# %% [markdown]
# ### Converting tif files to png files

# %%
from PIL import Image
import os

def convert_tif_to_png(tif_path, png_path):
    if not os.path.exists(png_path):
        os.makedirs(png_path)

    # Get the list of TIF files in the tif_path directory
    tif_files = [f for f in os.listdir(tif_path) if f.endswith('.tif')]

    for tif_file in tif_files:
        # Construct the full paths for TIF and PNG files
        tif_file_path = os.path.join(tif_path, tif_file)
        png_file_path = os.path.join(png_path, tif_file.replace('.tif', '.png'))

        # Skip the file if the corresponding PNG file already exists
        if os.path.exists(png_file_path):
            continue

        tif_image = Image.open(tif_file_path)

        # Ensure the TIF image has four channels (R, G, B, and an additional channel)
        if tif_image.mode != 'RGBA':
            print(tif_file)
            raise ValueError("The input TIF file should have 4 channels (RGBA).")

        # Separate the channels
        r, g, b, a = tif_image.split()

        # Create a new image with RGB mode (3 channels) and paste the RGB channels from the TIF
        rgb_image = Image.merge("RGB", (r, g, b))

        rgb_image.save(png_file_path)
        tif_image.close()

# %%
convert_tif_to_png("../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Dharmavaram_Elukuntla_2617200/GeoTiff/", "../Dataset/test_png_files/")

# %%
tif_directory = "Dataset/cropped_tif_files"
png_directory = "Dataset/cropped_png_files"

places = os.listdir(tif_directory)

for place in places:
    print(place)
    tif_place_path = os.path.join(tif_directory, place)
    png_place_path = os.path.join(png_directory, place)
    convert_tif_to_png(tif_place_path, png_place_path)

# %% [markdown]
# ### Removing unnecessary files

# %%
from PIL import Image
import os

# %%
def is_mostly_empty(image_path, threshold):
    image = Image.open(image_path)
    width, height = image.size
    pixel_data = list(image.getdata())

    non_white_pixel_count = 0
    for pixel in pixel_data:
        if pixel != (255, 255, 255):  # White pixel in RGB is (255, 255, 255)
            non_white_pixel_count += 1

    per = non_white_pixel_count/(1024*1024)
    per = per*100;
    # if(per<threshold):
    #     return True
    # return False
    return per

# %%
tif_directory = "Dataset/cropped_tif_files"
png_directory = "../Dataset/cropped_png_files"

places = os.listdir(png_directory)
below_15 = []
below_30 = []
below_20 = []
below_10 = []
for place in places:
    # print(place)
    png_place_path = os.path.join(png_directory, place)
    # Get the list of TIF files in the tif_path directory
    png_files = [f for f in os.listdir(png_place_path) if f.endswith('.png')]

    count = 0
    for png_file in png_files:
        png_file_path = os.path.join(png_place_path, png_file)
        per = is_mostly_empty(png_file_path, 10)
        if per<10:
            count += 1
            below_10.append(png_file_path)
        elif per<15:
            below_15.append(png_file_path)
        elif per<20:
            below_20.append(png_file_path)
        elif per<30:
            below_30.append(png_file_path)
    # print(count)
print(len(below_10))
print(len(below_15))
print(len(below_20))
print(len(below_30))

# %% [markdown]
# ### Get polygons of a particular tif file

# %%
import rasterio

def get_tif_bounding_box(tif_path):
    with rasterio.open(tif_path) as dataset:
        bounds = dataset.bounds
        min_x, min_y, max_x, max_y = bounds.left, bounds.bottom, bounds.right, bounds.top
        return (min_x, min_y, max_x, max_y)

# %%
# # Function to get the bounding box of the TIF file
# def get_tif_bounding_box(tif_path):
#     # Replace this with the appropriate code to obtain the bounding box from the TIF file.
#     # For example, using GDAL library to read raster metadata.
#     # Here's an example assuming you are using GDAL:
#     ds = gdal.Open(tif_path)
#     ulx, xres, xskew, uly, yskew, yres = ds.GetGeoTransform()
#     lrx = ulx + (ds.RasterXSize * xres)
#     lry = uly + (ds.RasterYSize * yres)
#     return (ulx, uly, lrx, lry)

# %%
def get_polygons_shp_file(shp_path):
    print(shp_path)
    # Open the shapefile and read the polygons:
    polygons = []
    with fiona.open(shp_path, "r") as shapefile:
        for feature in shapefile:
            geometry = shape(feature["geometry"])
            polygons.append((geometry, feature["properties"]))
    return polygons

# %%
def get_filtered_polygons(polygons, tif_path):
    # Get the bounding box of the TIF file
    tif_bbox = get_tif_bounding_box(tif_path)
    
    # Filter the polygons based on the intersection with the TIF file's bounding box:
    filtered_polygons = []
    for polygon, properties in polygons:
        polygon_bbox = polygon.bounds
        if box(*tif_bbox).intersects(box(*polygon_bbox)):
            filtered_polygons.append(polygon)

    return filtered_polygons

# %%
import fiona 
from shapely.geometry import shape, box

shp_path = "../Dataset/annotations/Chigicherla_Builtup_Area.shp"
tif_path = "../Dataset/cropped_tif_files/Chigicherla/Chigichrla_Ortho_H1_2_10.tif"

polygons = get_polygons_shp_file(shp_path)
filtered_polygons = get_filtered_polygons(polygons, tif_path)
print(len(filtered_polygons))

# %% [markdown]
# ### Create masks

# %%
import rasterio
# code to convert CRS coordinate to pixel coordinate
dataset = rasterio.open("../Dataset/cropped_tif_files/Chigicherla/Chigichrla_Ortho_H1_2_10.tif")
height = dataset.height
width = dataset.width
transform = dataset.transform

# %%
def fill_between(polygon):
    """
    Returns: a bool array
    """
    img = Image.new('1', (width, height), False)
    ImageDraw.Draw(img).polygon(polygon, outline=True, fill=True)
    mask = np.array(img)

    return mask

# %%
import numpy as np
from PIL import Image, ImageDraw

# Step 1: Initialize masks with the shape (height, width, number_of_polygons)
masks = np.zeros((height, width, len(filtered_polygons)), dtype=np.uint8)

# Step 2, 3, and 4: Loop through the filtered polygons, generate masks, and stack them
for idx, polygon in enumerate(filtered_polygons):
    coordinates = list()
    for point in polygon.exterior.coords:
        x, y = point
        pixel_x, pixel_y = ~transform * (x, y)
        pixel_x = width - 1 if pixel_x > width else pixel_x
        pixel_y = height - 1 if pixel_y > height else pixel_y
        coordinates.append((pixel_x, pixel_y))
    
    mask = fill_between(coordinates)
    masks[:, :, idx] = mask

# Step 5: Create a single image with different colors for each mask
unique_colors = np.random.randint(0, 255, (len(filtered_polygons), 3), dtype=np.uint8)
output_image = np.zeros((height, width, 3), dtype=np.uint8)

for idx, color in enumerate(unique_colors):
    mask_idx = np.where(masks[:, :, idx])
    output_image[mask_idx] = color

# Save the output image
output_image_pil = Image.fromarray(output_image)
output_image_pil.save('combined_masks.png')

# %% [markdown]
# ### Joining multiple tif files into one

# %%
import os
import rasterio
from rasterio.merge import merge
from rasterio.windows import Window
from rasterio.io import MemoryFile

# Define input and output directories
input_dir = "../Dataset/cropped_tif_files"
output_dir = "Results"

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# List all subdirectories in the input directory (representing places)
places = [f for f in os.listdir(input_dir) if os.path.isdir(os.path.join(input_dir, f))]

# Iterate through each place folder
for place in places:
    place_input_dir = os.path.join(input_dir, place)
    place_output_dir = os.path.join(output_dir, place)
    print(place)
    # Create place-specific output directory
    if not os.path.exists(place_output_dir):
        os.makedirs(place_output_dir)

    # List all TIFF files in the place folder
    tif_files = [f for f in os.listdir(place_input_dir) if f.endswith(".tif")]

    # Create an empty list to store datasets
    datasets = []

    # Open each TIFF file and append it to the list of datasets
    for tif_file in tif_files:
        image_path = os.path.join(place_input_dir, tif_file)
        dataset = rasterio.open(image_path)
        datasets.append(dataset)

    # Merge the datasets into a single dataset
    merged, out_transform = merge(datasets)

    # Create an output file path
    output_image_path = os.path.join(place_output_dir, "output.tif")

    # Update the metadata for the merged dataset
    out_meta = datasets[0].meta.copy()
    out_meta.update({"driver": "GTiff", "height": merged.shape[1], "width": merged.shape[2], "transform": out_transform})

    # Write the merged dataset to the output file
    with MemoryFile() as memfile:
        with memfile.open(**out_meta) as dest:
            dest.write(merged)
        with open(output_image_path, "wb") as f:
            f.write(memfile.read())

print("TIFF files have been joined and saved in the 'Results' directory using rasterio.")

# %% [markdown]
# ### Convert palette tif to full color rgb

# %%
def convert_palette_tiff_to_full_color(input_tif_path, output_tif_path):
    # Open the input TIFF file with geospatial information
    input_tif = rasterio.open(input_tif_path)
    
    if(input_tif.count==1):
        print(input_tif_path, "has only one channel")
    return

    # Check if the input TIFF file already has an RGB band (3 bands)
    if input_tif.count == 3 or input_tif.count==4:
        print("The input TIFF file already has an RGB band. No conversion needed.")
        return  

    # Load the palette color TIFF image
    palette_color_image = Image.open(input_tif_path)

    # Convert the palette color image to RGB mode
    palette_color_image_rgb = palette_color_image.convert('RGB')

    # Get the dimensions of the full-color image
    width, height = palette_color_image_rgb.size

    # Create a new TIFF file with the same dimensions and transformation as the input TIFF
    with rasterio.open(output_tif_path, 'w', driver='GTiff', width=width, height=height, count=3, dtype='uint8', crs=input_tif.crs, transform=input_tif.transform) as dst:
        # Convert the full-color image to a NumPy array
        image_data = np.array(palette_color_image_rgb)

        # Make sure the image data is in the correct order (height, width, channels)
        image_data = np.moveaxis(image_data, -1, 0)

        # Write the full-color image data to the TIFF file
        dst.write(image_data, indexes=(1, 2, 3))

    # Close the output TIFF file
    dst.close()

# %%
tif_directory = "../Dataset/Orthos_DSMs_Shapefiles/"

places = os.listdir(tif_directory)

for place in places:
    print(place)
    tif_place_path = os.path.join(tif_directory, place)
    tif_place_path = os.path.join(tif_place_path, 'GeoTiff')
    output_tif_place_path = os.path.join(tif_directory, place)
    output_tif_place_path = os.path.join(output_tif_place_path, "GeoTiff2")

    if not os.path.exists(output_tif_place_path):
        os.makedirs(output_tif_place_path)

    # Get the list of TIF files in the tif_path directory
    tif_files = [f for f in os.listdir(tif_place_path) if f.endswith('.tif')]

    for tif_file in tif_files:
        # Construct the full paths for TIF and PNG files
        tif_file_path = os.path.join(tif_place_path, tif_file)
        output_tif_file_path = os.path.join(output_tif_place_path, tif_file) 

        # # Skip the file if the corresponding PNG file already exists
        # if os.path.exists(output_tif_file_path):
        #     continue

        convert_palette_tiff_to_full_color(tif_file_path, output_tif_file_path)
# Out:
# Dharmavaram_Ramagiri_Ramagiri_2633100
# Dharmavaram_Dharmavaram_Elukuntla_2617200
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Dharmavaram_Elukuntla_2617200/GeoTiff/Elukuntala_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Dharmavaram_Elukuntla_2617200/GeoTiff/Elukuntala_Ortho_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Dharmavaram_Elukuntla_2617200/GeoTiff/Elukuntala_Ortho_H3.tif has only one channel
# Dharmavaram_Ramagiri_Polepalli_2633400
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Ramagiri_Polepalli_2633400/GeoTiff/Polepalli_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Ramagiri_Polepalli_2633400/GeoTiff/Polepalli_Ortho_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Ramagiri_Polepalli_2633400/GeoTiff/Polepalli_Ortho_H3.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Ramagiri_Polepalli_2633400/GeoTiff/Polepalli_Ortho_H4.tif has only one channel
# Dharmavaram_chennekothapalli_Mushtikovela_2631500
# Dharmavaram_Dharmavaram_Nelakota_2617000
# Dharmavaram_Mudigubba_Devargudapalli_2621700
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Devargudapalli_2621700/GeoTiff/Devaragudipalle_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Devargudapalli_2621700/GeoTiff/Devaragudipalle_Ortho_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Devargudapalli_2621700/GeoTiff/Devaragudipalle_Ortho_H3.tif has only one channel
# Dharmavaram_Bathalapalli_APPARACHERUVU_2617700
# Dharmavaram_Mudigubba_Thapettevaripalli_2622000
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Thapettevaripalli_2622000/GeoTiff/Thappetavaripalli_Ortho_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Thapettevaripalli_2622000/GeoTiff/Thappetavaripalli_Ortho_H2.tif has only one channel
# Dharmavaram_Kanaganapalle_K.N.Palyam_2615300
# Puttaparthi_Nallamada_Gopepalli_02627900
# Dharmavaram_Mudigubba_MALAKAVEMULA_2621500
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_MALAKAVEMULA_2621500/GeoTiff/Malakavemula_ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_MALAKAVEMULA_2621500/GeoTiff/Malakavemula_ortho_H1.tif has only one channel
# Dharmavaram_Mudigubba_Budhanampalli_2619600
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Budhanampalli_2619600/GeoTiff/Budanampalli_Ortho_H3.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Budhanampalli_2619600/GeoTiff/Budanampalli_Ortho_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Budhanampalli_2619600/GeoTiff/Budanampalli_Ortho_H2.tif has only one channel
# Dharmavaram_Tadimarri_Kunukuntla_2618500
# Dharmavaram_Tadimarri_DADITHOTA_2618700
# Dharmavaram_Tadimarri_Pinnadari_2618400
# Puttaparthi_Kothacheruvu_Virupapuram_2631000
# Kadiri_Tanakallu_DanduvariPalli_2621700
# Dharmavaram_Mudigubba_Mangalamadaka_2621200
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Mangalamadaka_2621200/GeoTiff/MANGALAMADAKA_Ortho_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Mangalamadaka_2621200/GeoTiff/MANGALAMADAKA_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Mangalamadaka_2621200/GeoTiff/MANGALAMADAKA_Ortho_H4.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Mangalamadaka_2621200/GeoTiff/MANGALAMADAKA_Ortho_H3.tif has only one channel
# Dharmavaram_Mudigubba_SANEVARIPALLI_2621600
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_SANEVARIPALLI_2621600/GeoTiff/Sanevaripalli_Ortho_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_SANEVARIPALLI_2621600/GeoTiff/Sanevaripalli_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_SANEVARIPALLI_2621600/GeoTiff/Sanevaripalli_Ortho_H4.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_SANEVARIPALLI_2621600/GeoTiff/Sanevaripalli_Ortho_H3.tif has only one channel
# Kadiri_Amadaguru_Karimireddipalli_2651600
# Dharmavaram_Mudigubba_KONDAGATTUPALLI_2622100
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_KONDAGATTUPALLI_2622100/GeoTiff/Kondagattupalli_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_KONDAGATTUPALLI_2622100/GeoTiff/Kondagattupalli_Ortho_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_KONDAGATTUPALLI_2622100/GeoTiff/Kondagattupalli_Ortho_H3.tif has only one channel
# Kadiri_Nallacheruvu_Panthulacheruvu_02647400
# Dharmavaram_Bathalapalli_MALYAVANTHAM_2617400
# Dharmavaram_Ramagiri_Ganthimarri_2633200
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Ramagiri_Ganthimarri_2633200/GeoTiff/Ganthimarri_geotiff_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Ramagiri_Ganthimarri_2633200/GeoTiff/Ganthimarri_geotiff_H3.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Ramagiri_Ganthimarri_2633200/GeoTiff/Ganthimarri_geotiff_H2.tif has only one channel
# Kadiri_Tanakallu_Venkatarayani Palli_02650000
# Dharmavaram_Dharmavaram_Darsimala_2616900
# Dharmavaram_Mudigubba_B D Marri_2620100
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_B D Marri_2620100/GeoTiff/BD_Marri_Ortho_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_B D Marri_2620100/GeoTiff/BD_Marri_Ortho_H2.tif has only one channel
# Dharmavaram_Tadimarri_Nidigallu_2619200
# Dharmavaram_Ramagiri_M.Chinthala palli_2632900
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Ramagiri_M.Chinthala palli_2632900/GeoTiff/Motarchinthalapalli_Ortho_H3.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Ramagiri_M.Chinthala palli_2632900/GeoTiff/Motarchinthalapalli_Ortho_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Ramagiri_M.Chinthala palli_2632900/GeoTiff/Motarchinthalapalli_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Ramagiri_M.Chinthala palli_2632900/GeoTiff/Motarchinthalapalli_Ortho_H4.tif has only one channel
# Dharmavaram_Kanaganapalle_Tumcherla_2615000
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Kanaganapalle_Tumcherla_2615000/GeoTiff/Tumcherla_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Kanaganapalle_Tumcherla_2615000/GeoTiff/Tumcherla_Ortho_H3.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Kanaganapalle_Tumcherla_2615000/GeoTiff/Tumcherla_Ortho_H4.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Kanaganapalle_Tumcherla_2615000/GeoTiff/Tumcherla_Ortho_H1.tif has only one channel
# Dharmavaram_Kanaganpalli_Narasampalli_2615400
# Dharmavaram_Dharmavaram_Gotluru_2616100
# Dharmavaram_chennekothapalli_Kanumukkala_2632200
# Dharmavaram_chennekothapalli_Brahmanapalli_2632500
# Dharmavaram_Mudigubba_Uppalapadu_2620300
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Uppalapadu_2620300/GeoTiff/UPPALAPADU_Ortho_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Uppalapadu_2620300/GeoTiff/UPPALAPADU_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Uppalapadu_2620300/GeoTiff/UPPALAPADU_Ortho_H3.tif has only one channel
# Dharmavaram_Mudigubba_Sankepalle_2620600
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Sankepalle_2620600/GeoTiff/SANKEPALLE_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Sankepalle_2620600/GeoTiff/SANKEPALLE_Ortho_H7.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Sankepalle_2620600/GeoTiff/SANKEPALLE_Ortho_H5.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Sankepalle_2620600/GeoTiff/SANKEPALLE_Ortho_H3.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Sankepalle_2620600/GeoTiff/SANKEPALLE_Ortho_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Sankepalle_2620600/GeoTiff/SANKEPALLE_Ortho_H6.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Sankepalle_2620600/GeoTiff/SANKEPALLE_Ortho_H4.tif has only one channel
# Dharmavaram_Mudigubba_MUKTHAPURAM_2620400
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_MUKTHAPURAM_2620400/GeoTiff/Mukthapuram_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_MUKTHAPURAM_2620400/GeoTiff/Mukthapuram_Ortho_H3.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_MUKTHAPURAM_2620400/GeoTiff/Mukthapuram_Ortho_H1.tif has only one channel
# Dharmavaram_Ramagiri_Kondapuram_2632800
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Ramagiri_Kondapuram_2632800/GeoTiff/Kondavaram_ortho_HAB_2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Ramagiri_Kondapuram_2632800/GeoTiff/Kondavaram_ortho_HAB_1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Ramagiri_Kondapuram_2632800/GeoTiff/Kondavaram_ortho_HAB_3.tif has only one channel
# Dharmavaram_Mudigubba_YELLAREDDYPALLI_2621800
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_YELLAREDDYPALLI_2621800/GeoTiff/Yellaredipalle_Ortho_H1.tif has only one channel
# Dharmavaram_Bathalapalli_SANGALA_2617900
# Dharmavaram_Tadimarri_PEDDAKOTLA_2618800
# Dharmavaram_Ramagiri_Kuntimaddi_2633300
# Kadiri_Amadaguru_Ramanatha puram_2651200
# Dharmavaram_Mudigubba_Marthadu_2619800
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Marthadu_2619800/GeoTiff/Marthadu_Ortho_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Marthadu_2619800/GeoTiff/Marthadu_Ortho_H2.tif has only one channel
# Dampetla
# Dharmavaram_Mudigubba_S.Brahamanapalli_2620700
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_S.Brahamanapalli_2620700/GeoTiff/S_Brahmanapalli_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_S.Brahamanapalli_2620700/GeoTiff/S_Brahmanapalli_Ortho_H1.tif has only one channel
# Dharmavaram_Kanaganapalle_Mukthapuram_2615800
# Dharmavaram_chennekothapalli_Nagasamudram_2631800
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_chennekothapalli_Nagasamudram_2631800/GeoTiff/Nagasamudram_Ortho_H6.tif has only one channel
# Dharmavaram_chennekothapalli_Veldurthy_2632300
# Dharmavaram_chennekothapalli_Ganginepalli_2632400
# Chigicherla
# Kadiri_Amadaguru_Cheekirevulapalli_2651500
# Kadiri_Nallacheruvu_Tavalamarri_02647900
# Kadiri_Tanakallu_MundlavariPalli_02649900
# Puttaparthi_Nallamada_Chowtakuntapalli _2628000
# Dharmavaram_Tadimarri_CHILLAVARIPALLI_2618600
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Tadimarri_CHILLAVARIPALLI_2618600/GeoTiff/Chillavaripalli_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Tadimarri_CHILLAVARIPALLI_2618600/GeoTiff/Chillavaripalli_Ortho_H1.tif has only one channel
# Dharmavaram_Mudigubba_NAGAREDDYPALLI_2621400
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_NAGAREDDYPALLI_2621400/GeoTiff/Nagareddypalli_Ortho_H1.tif has only one channel
# Dharmavaram_Kanaganapalle_Dadulur_2615900
# Dharmavaram_Dharmavaram_Thummala_2616300
# Dharmavaram_Bathalapalli_GARISELEPALE_2618100
# Dharmavaram_Tadimarri_C.C. REVU_2619400
# Dharmavaram_Dharmavaram_Mallakaluva_2616800
# Dharmavaram_Mudigubba_CHINNAKOTALA_2619500
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_CHINNAKOTALA_2619500/GeoTiff/CHINNAKOTLA_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_CHINNAKOTALA_2619500/GeoTiff/CHINNAKOTLA_Ortho_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_CHINNAKOTALA_2619500/GeoTiff/CHINNAKOTLA_Ortho_H3.tif has only one channel
# Dharmavaram_Mudigubba_JKPALLI_2620500
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_JKPALLI_2620500/GeoTiff/JK_Palli_Ortho_H6.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_JKPALLI_2620500/GeoTiff/JK_Palli_Ortho_H3.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_JKPALLI_2620500/GeoTiff/JK_Palli_Ortho_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_JKPALLI_2620500/GeoTiff/JK_Palli_Ortho_H7.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_JKPALLI_2620500/GeoTiff/JK_Palli_Ortho_H5.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_JKPALLI_2620500/GeoTiff/JK_Palli_Ortho_H4.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_JKPALLI_2620500/GeoTiff/JK_Palli_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_JKPALLI_2620500/GeoTiff/JK_Palli_Ortho_H8.tif has only one channel
# Dharmavaram_Mudigubba_T.N.palayam_2620900
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_T.N.palayam_2620900/GeoTiff/TN PALAYAM_Ortho_H1.tif has only one channel
# Dharmavaram_Mudigubba_Kodavanllapalli_2619700
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Kodavanllapalli_2619700/GeoTiff/Kodavanapalli_Ortho_H4.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Kodavanllapalli_2619700/GeoTiff/Kodavanapalli_Ortho_H3.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Kodavanllapalli_2619700/GeoTiff/Kodavanapalli_Ortho_HAB1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Kodavanllapalli_2619700/GeoTiff/Kodavanapalli_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Kodavanllapalli_2619700/GeoTiff/Kodavanapalli_Ortho_HAB5.tif has only one channel
# Dharmavaram_chennekothapalli_Pulletipalli_2632100
# Obulapuram
# Kadiri_Talupula_Lakkasamudram_02622300
# ../Dataset/Orthos_DSMs_Shapefiles/Kadiri_Talupula_Lakkasamudram_02622300/GeoTiff/Lakkasamudram_Ortho_H7.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Kadiri_Talupula_Lakkasamudram_02622300/GeoTiff/Lakkasamudram_Ortho_H5.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Kadiri_Talupula_Lakkasamudram_02622300/GeoTiff/Lakkasamudram_Ortho_H3.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Kadiri_Talupula_Lakkasamudram_02622300/GeoTiff/Lakkasamudram_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Kadiri_Talupula_Lakkasamudram_02622300/GeoTiff/Lakkasamudram_Ortho_H1.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Kadiri_Talupula_Lakkasamudram_02622300/GeoTiff/Lakkasamudram_Ortho_H4.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Kadiri_Talupula_Lakkasamudram_02622300/GeoTiff/Lakkasamudram_Ortho_H6.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Kadiri_Talupula_Lakkasamudram_02622300/GeoTiff/Lakkasamudram_Ortho_H8.tif has only one channel
# Dharmavaram_Mudigubba_S.bandhalapalli_2619900
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_S.bandhalapalli_2619900/GeoTiff/S.bandhalapalli_Ortho_H1.tif has only one channel
# Dharmavaram_Mudigubba_Peddachigullarevu(P.C Revu)_2620200
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Peddachigullarevu(P.C Revu)_2620200/GeoTiff/PC_REVU_Ortho_H3.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Peddachigullarevu(P.C Revu)_2620200/GeoTiff/PC_REVU_Ortho_H2.tif has only one channel
# ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Mudigubba_Peddachigullarevu(P.C Revu)_2620200/GeoTiff/PC_REVU_Ortho_H1.tif has only one channel
# Kadiri_Nallacheruvu_Maddimadugu_02647800
