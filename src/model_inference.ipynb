# %% [markdown]
# ### Importing Libraries and Defining Paths

# %%
from warnings import filterwarnings
filterwarnings(action='ignore', category=DeprecationWarning, message='`np.bool` is a deprecated alias')
filterwarnings('ignore')

# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import cv2
import matplotlib
import fiona 
from shapely.geometry import shape, box
import rasterio
from PIL import Image, ImageDraw
Image.MAX_IMAGE_PIXELS = None
import tensorflow as tf
import imgaug.augmenters as iaa
import matplotlib.pyplot as plt
# %matplotlib inline 
from patchify import patchify, unpatchify
from shapely.geometry import Polygon, MultiPolygon
import geopandas as gpd
import copy

# %%
# Root directory of the project
ROOT_DIR = os.path.abspath("../")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
sys.path.append(os.path.join(ROOT_DIR, "mrcnn"))

# %%
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log

# %%
# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

DATASET_DIR = os.path.join(ROOT_DIR, "Dataset")

# Local path to trained weights file
COCO_MODEL_PATH = "../models/mask_rcnn_coco.h5"
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

# %%
# Check if GPU is available
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Configurations

# %%
class TrainingConfig(Config):
    NAME = "BuildingDetection"
    GPU_COUNT = 1
    IMAGES_PER_GPU = 4
    STEPS_PER_EPOCH = 2770
    VALIDATION_STEPS = 234
    BACKBONE = "resnet101"
    NUM_CLASSES = 2 #bulding and background
    IMAGE_MAX_DIM = 1024
    IMAGE_MIN_DIM = 1024

    TRAIN_ROIS_PER_IMAGE = 50
    
    MAX_GT_INSTANCES = 50
    LOSS_WEIGHTS = {
        "rpn_class_loss": 2.,
        "rpn_bbox_loss": 1.,
        "mrcnn_class_loss": 1.,
        "mrcnn_bbox_loss": 1.,
        "mrcnn_mask_loss": 10.
    }

# %%
class InferenceConfig(TrainingConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1
    DETECTION_MIN_CONFIDENCE = 0.9

inference_config = InferenceConfig()

# %%
model_inference = modellib.MaskRCNN(mode="inference", config=inference_config, model_dir=MODEL_DIR)

# %% [markdown]
# ### Inference

# %%
# Get path to saved weights
# Either set a specific path or find last trained weights
model_path = os.path.join(MODEL_DIR, "buildingdetection20230801T1248/mask_rcnn_buildingdetection_0041.h5")
# model_path = model_inference.find_last()

# Load trained weights
print("Loading weights from ", model_path)
model_inference.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  /home/cctv/Internship/Building_detection/logs/buildingdetection20230801T1248/mask_rcnn_buildingdetection_0041.h5
# 2023-09-24 17:40:31.634260: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-24 17:40:31.641806: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:51:00.0 name: NVIDIA A30 computeCapability: 8.0
# coreClock: 1.44GHz coreCount: 56 deviceMemorySize: 23.50GiB deviceMemoryBandwidth: 869.04GiB/s
# 2023-09-24 17:40:31.646473: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-09-24 17:40:31.646542: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-09-24 17:40:31.817110: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-09-24 17:40:31.817137: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-09-24 17:40:31.817143: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-09-24 17:40:31.822418: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22275 MB memory) -> physical GPU (device: 0, name: NVIDIA A30, pci bus id: 0000:51:00.0, compute capability: 8.0)
# 2023-09-24 17:40:32.532017: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2900000000 Hz
# Re-starting from epoch 41

# %% [markdown]
# #### Run inference on multiple files

# %%
def extract_patches(image_path, patch_size, step):
    """
    Extract patches from an image and return the patches along with a padded image.

    Args:
        image_path (str): Path to the input image.
        patch_size (tuple): Size of each patch in (height, width) format.
        step (int): Step size for patch extraction.

    Returns:
        patches (numpy.ndarray): Extracted patches.
        padded_image (numpy.ndarray): Padded image to fit patches evenly.
    """
    # Open the image
    image = Image.open(image_path)
    
    # Convert the PIL image to a NumPy array
    image_np = np.array(image)
    
    # Calculate the number of patches in each dimension
    num_patches_y = (image_np.shape[0] + patch_size[0] - 1) // patch_size[0]
    num_patches_x = (image_np.shape[1] + patch_size[1] - 1) // patch_size[1]
    
    # Calculate the required padding to fit the patches evenly
    pad_y = num_patches_y * patch_size[0] - image_np.shape[0]
    pad_x = num_patches_x * patch_size[1] - image_np.shape[1]
    
    # Pad the image
    
    if(len(image_np.shape)<3):
        print("RGB channels missing in", image_path)
        return [], []
    else:
        padded_image = np.pad(image_np, ((0, pad_y), (0, pad_x), (0, 0)), mode='constant')
    
    # Divide the padded image into patches
    patches = patchify(padded_image, patch_size, step=step)
    
    return patches, padded_image

# %%
def is_mask_on_edge(mask, edge_percentage, mask_percentage):
    """
    Check if a mask is present on the edges of an image.

    Args:
        mask (numpy.ndarray): Binary mask.
        edge_percentage (float): Percentage of edges to consider (0 to 1).
        mask_percentage (float): Minimum percentage of mask pixels on an edge (0 to 1).

    Returns:
        bool: True if mask is on any edge, False otherwise.
    """
    height, width = mask.shape
    total_mask_area = np.sum(mask)
    edge_pixels = int(min(height, width) * edge_percentage)

    # Check top edge
    if np.sum(mask[:edge_pixels, :]) >= mask_percentage * total_mask_area:
        return True
    
    # Check bottom edge
    if np.sum(mask[-edge_pixels:, :]) >= mask_percentage * total_mask_area:
        return True
    
    # Check left edge
    if np.sum(mask[:, :edge_pixels]) >= mask_percentage * total_mask_area:
        return True
    
    # Check right edge
    if np.sum(mask[:, -edge_pixels:]) >= mask_percentage * total_mask_area:
        return True
    
    return False

# %%
def find_polygons(r, x, y, eps = 0.02):
    """
    Find polygons from instance segmentation results.

    Args:
        r (dict): Result dictionary containing masks and bounding boxes.
        x (int): X-coordinate shift.
        y (int): Y-coordinate shift.
        eps (float, optional): Epsilon value for polygon approximation. 
            Controls the precision of the approximation. Default is 0.02.

    Returns:
        polygons (list): List of Shapely Polygon objects representing objects.
    """
    masks = r['masks']
    bboxes = r['rois']
    n = bboxes.shape[0]
    polygons = []
    
    for i in range(n):
        mask = masks[:, :, i]
        mask = mask.astype(np.uint8)

        # Ignore incomplete building masks on sides of images
        if is_mask_on_edge(mask, 0.2, 0.5):
            continue
        
        contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        
        for contour in contours:
            epsilon = eps * cv2.arcLength(contour, True)
            approx = cv2.approxPolyDP(contour, epsilon, closed=False)
            
            shifted_polygon = np.array(approx) + np.array([x, y])
            
            # Convert the shifted_polygon to a GeoDataFrame Polygon
            poly_coords = [(point[0][0], point[0][1]) for point in shifted_polygon]
            if len(poly_coords) >= 4:
                polygon = Polygon(poly_coords)
                polygons.append(polygon)
            
    return polygons

# %%
def apply_patch_overlap_adjustment(polygons, prev_polygons, overlap_threshold):
    adjusted_polygons = []
    for polygon in polygons:
        if (polygon.is_valid and prev_poly.is_valid() and not any(polygon.intersection(prev_poly).area >= overlap_threshold * polygon.area) for prev_poly in prev_polygons):
            adjusted_polygons.append(polygon)
    return adjusted_polygons

# %%
def process_patches_with_overlap_adjustment(image_path, patches, model_inference, step, overlap_threshold, output_shp_path):
    # Open the input image
    image = Image.open(image_path)
    image_width, image_height = image.size
    draw = ImageDraw.Draw(image)

    # Extract CRS from the TIFF image
    with rasterio.open(image_path) as src:
        transform = src.transform
        crs = src.crs
    
    # Initialize a 2D list to store polygons for each patch
    patch_polygons = [[[] for _ in range(patches.shape[1])] for _ in range(patches.shape[0])]
    
    # Create a list to store all polygons for the shapefile
    all_polygons = []

    for i in range(patches.shape[0]):
        for j in range(patches.shape[1]):
            # Extract the current patch
            patch = patches[i, j, 0, :, :, :3]
            
            # Perform model inference to detect objects in the patch
            r = model_inference.detect([patch])[0]
            
            # Find polygons from the detection results and adjust for overlap
            polygons = find_polygons(r, j * step, i * step)
            
            # Apply overlap adjustment with the previous row
            if i > 0:
                prev_row_polygons = patch_polygons[i - 1][j]
                polygons = apply_patch_overlap_adjustment(polygons, prev_row_polygons, overlap_threshold)
            
            # Apply overlap adjustment with the previous column
            if j > 0:
                prev_col_polygons = patch_polygons[i][j - 1]
                polygons = apply_patch_overlap_adjustment(polygons, prev_col_polygons, overlap_threshold)
            
            # Apply overlap adjustment with the diagonal patch (top-left)
            if i > 0 and j > 0:
                prev_diag_polygons = patch_polygons[i - 1][j - 1]
                polygons = apply_patch_overlap_adjustment(polygons, prev_diag_polygons, overlap_threshold)
            
            # Apply overlap adjustment with the diagonal patch (top-right)
            if i > 0 and j < patches.shape[1]-1:
                prev_diag_polygons = patch_polygons[i - 1][j + 1]
                polygons = apply_patch_overlap_adjustment(polygons, prev_diag_polygons, overlap_threshold)
            
            # Store the adjusted polygons in the 2D list
            patch_polygons[i][j] = polygons

            # Append the adjusted polygons to the list of all polygons
            all_polygons.extend(polygons)
            
            # Print a message to indicate patch processing completion
            print(f"Patch {i},{j} completed")

    # Transform polygon coordinates from pixel to the TIFF file's coordinate system
    transformed_polygons = []
    for polygon in all_polygons:
        points = []
        for point in polygon.exterior.coords:
            x, y = point
            lon, lat = transform * (x + 0.5, y + 0.5)
            points.append((lon, lat))
        transformed_polygons.append(Polygon(points))

    # Create a GeoDataFrame from the list of transformed polygons
    geometry = gpd.GeoSeries(transformed_polygons)
    print(len(all_polygons))
    gdf = gpd.GeoDataFrame(geometry=geometry, crs=crs)  # You might need to adjust the CRS
    
    # Save the GeoDataFrame as a shapefile
    gdf.to_file(output_shp_path)

# %%
overlap_threshold = 0.5  # Adjust this threshold as needed
patch_size = (1024, 1024, 3)  # Adjust this to the desired patch size and channel count
step = 512
input_folder = "../Dataset/Orthos_DSMs_Shapefiles/"
output_folder = "../results"

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate over folders in the input directory
for tif_folder in os.listdir(input_folder):
    geotiff_folder = os.path.join(input_folder, tif_folder)
    geotiff_folder = os.path.join(geotiff_folder, "GeoTiff2")
    curr_output_folder = os.path.join(output_folder, tif_folder)
    
    # Create output folder if it doesn't exist
    if not os.path.exists(curr_output_folder):
        os.makedirs(curr_output_folder)

    # Iterate over files in the GeoTiff folder
    for filename in os.listdir(geotiff_folder):    
        if filename.endswith(".tif"):
            input_path = os.path.join(geotiff_folder, filename)
            print("Working on", input_path)

            inside_folder = os.path.join(curr_output_folder, f"{filename[:-4]}")
            
            # Create a subfolder for each input file
            if not os.path.exists(inside_folder):
                os.makedirs(inside_folder)

            # if len(os.listdir(inside_folder))==0:
            #     os.rmdir(inside_folder)
            #     print("deleting", inside_folder)
            #     continue
 
            output_path = os.path.join(inside_folder, f"output_{filename[:-4]}"+"_palette_file.shp")
            print("Output path:", output_path)
            
            # Skip processing if the output file already exists
            if os.path.exists(output_path):
                continue
            
            # Extract patches from the input image
            patches, padded_image = extract_patches(input_path, patch_size, step)\
            
            # Process patches with overlap adjustment and save results as a shapefile
            if(len(patches)):
                process_patches_with_overlap_adjustment(input_path, patches, model_inference, step, overlap_threshold, output_path)
# Out:
# Working on ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Dharmavaram_Elukuntla_2617200/GeoTiff2/Elukuntala_Ortho_H2.tif
# Output path: ../results/Dharmavaram_Dharmavaram_Elukuntla_2617200/Elukuntala_Ortho_H2/output_Elukuntala_Ortho_H2_palette_file.shp
# Patch 0,0 completed
# Patch 0,1 completed
# Patch 0,2 completed
# Patch 0,3 completed
# Patch 0,4 completed
# Patch 0,5 completed
# Patch 0,6 completed
# Patch 0,7 completed
# Patch 0,8 completed
# Patch 0,9 completed
# Patch 0,10 completed
# Patch 0,11 completed
# Patch 0,12 completed
# Patch 0,13 completed
# Patch 0,14 completed
# Patch 1,0 completed
# Patch 1,1 completed
# Patch 1,2 completed
# Patch 1,3 completed
# Patch 1,4 completed
# Patch 1,5 completed
# Patch 1,6 completed
# Patch 1,7 completed
# Patch 1,8 completed
# Patch 1,9 completed
# Patch 1,10 completed
# Patch 1,11 completed
# Patch 1,12 completed
# Patch 1,13 completed
# Patch 1,14 completed
# Patch 2,0 completed
# Patch 2,1 completed
# Patch 2,2 completed
# Patch 2,3 completed
# Patch 2,4 completed
# Patch 2,5 completed
# Patch 2,6 completed
# Patch 2,7 completed
# Patch 2,8 completed
# Patch 2,9 completed
# Patch 2,10 completed
# Patch 2,11 completed
# Patch 2,12 completed
# Patch 2,13 completed
# Patch 2,14 completed
# Patch 3,0 completed
# Patch 3,1 completed
# Patch 3,2 completed
# Patch 3,3 completed
# Patch 3,4 completed
# Patch 3,5 completed
# Patch 3,6 completed
# Patch 3,7 completed
# Patch 3,8 completed
# Patch 3,9 completed
# Patch 3,10 completed
# Patch 3,11 completed
# Patch 3,12 completed
# Patch 3,13 completed
# Patch 3,14 completed
# Patch 4,0 completed
# Patch 4,1 completed
# Patch 4,2 completed
# Patch 4,3 completed
# Patch 4,4 completed
# Patch 4,5 completed
# Patch 4,6 completed
# Patch 4,7 completed
# Patch 4,8 completed
# Patch 4,9 completed
# Patch 4,10 completed
# Patch 4,11 completed
# Patch 4,12 completed
# Patch 4,13 completed
# Patch 4,14 completed
# Patch 5,0 completed
# Patch 5,1 completed
# Patch 5,2 completed
# Patch 5,3 completed
# Patch 5,4 completed
# Patch 5,5 completed
# Patch 5,6 completed
# Patch 5,7 completed
# Patch 5,8 completed
# Patch 5,9 completed
# Patch 5,10 completed
# Patch 5,11 completed
# Patch 5,12 completed
# Patch 5,13 completed
# Patch 5,14 completed
# Patch 6,0 completed
# Patch 6,1 completed
# Patch 6,2 completed
# Patch 6,3 completed
# Patch 6,4 completed
# Patch 6,5 completed
# Patch 6,6 completed
# Patch 6,7 completed
# Patch 6,8 completed
# Patch 6,9 completed
# Patch 6,10 completed
# Patch 6,11 completed
# Patch 6,12 completed
# Patch 6,13 completed
# Patch 6,14 completed
# Patch 7,0 completed
# Patch 7,1 completed
# Patch 7,2 completed
# Patch 7,3 completed
# Patch 7,4 completed
# Patch 7,5 completed
# Patch 7,6 completed
# Patch 7,7 completed
# Patch 7,8 completed
# Patch 7,9 completed
# Patch 7,10 completed
# Patch 7,11 completed
# Patch 7,12 completed
# Patch 7,13 completed
# Patch 7,14 completed
# Patch 8,0 completed
# Patch 8,1 completed
# Patch 8,2 completed
# Patch 8,3 completed
# Patch 8,4 completed
# Patch 8,5 completed
# Patch 8,6 completed
# Patch 8,7 completed
# Patch 8,8 completed
# Patch 8,9 completed
# Patch 8,10 completed
# Patch 8,11 completed
# Patch 8,12 completed
# Patch 8,13 completed
# Patch 8,14 completed
# 131
# Working on ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Dharmavaram_Elukuntla_2617200/GeoTiff2/Elukuntala_Ortho_H1.tif
# Output path: ../results/Dharmavaram_Dharmavaram_Elukuntla_2617200/Elukuntala_Ortho_H1/output_Elukuntala_Ortho_H1_palette_file.shp
# Patch 0,0 completed
# Patch 0,1 completed
# Patch 0,2 completed
# Patch 0,3 completed
# Patch 0,4 completed
# Patch 0,5 completed
# Patch 0,6 completed
# Patch 0,7 completed
# Patch 0,8 completed
# Patch 0,9 completed
# Patch 0,10 completed
# Patch 0,11 completed
# Patch 0,12 completed
# Patch 0,13 completed
# Patch 0,14 completed
# Patch 1,0 completed
# Patch 1,1 completed
# Patch 1,2 completed
# Patch 1,3 completed
# Patch 1,4 completed
# Patch 1,5 completed
# Patch 1,6 completed
# Patch 1,7 completed
# Patch 1,8 completed
# Patch 1,9 completed
# Patch 1,10 completed
# Patch 1,11 completed
# Patch 1,12 completed
# Patch 1,13 completed
# Patch 1,14 completed
# Patch 2,0 completed
# Patch 2,1 completed
# Patch 2,2 completed
# Patch 2,3 completed
# Patch 2,4 completed
# Patch 2,5 completed
# Patch 2,6 completed
# Patch 2,7 completed
# Patch 2,8 completed
# Patch 2,9 completed
# Patch 2,10 completed
# Patch 2,11 completed
# Patch 2,12 completed
# Patch 2,13 completed
# Patch 2,14 completed
# Patch 3,0 completed
# Patch 3,1 completed
# Patch 3,2 completed
# Patch 3,3 completed
# Patch 3,4 completed
# Patch 3,5 completed
# Patch 3,6 completed
# Patch 3,7 completed
# Patch 3,8 completed
# Patch 3,9 completed
# Patch 3,10 completed
# Patch 3,11 completed
# Patch 3,12 completed
# Patch 3,13 completed
# Patch 3,14 completed
# Patch 4,0 completed
# Patch 4,1 completed
# Patch 4,2 completed
# Patch 4,3 completed
# Patch 4,4 completed
# Patch 4,5 completed
# Patch 4,6 completed
# Patch 4,7 completed
# Patch 4,8 completed
# Patch 4,9 completed
# Patch 4,10 completed
# Patch 4,11 completed
# Patch 4,12 completed
# Patch 4,13 completed
# Patch 4,14 completed
# Patch 5,0 completed
# Patch 5,1 completed
# Patch 5,2 completed
# Patch 5,3 completed
# Patch 5,4 completed
# Patch 5,5 completed
# Patch 5,6 completed
# Patch 5,7 completed
# Patch 5,8 completed
# Patch 5,9 completed
# Patch 5,10 completed
# Patch 5,11 completed
# Patch 5,12 completed
# Patch 5,13 completed
# Patch 5,14 completed
# Patch 6,0 completed
# Patch 6,1 completed
# Patch 6,2 completed
# Patch 6,3 completed
# Patch 6,4 completed
# Patch 6,5 completed
# Patch 6,6 completed
# Patch 6,7 completed
# Patch 6,8 completed
# Patch 6,9 completed
# Patch 6,10 completed
# Patch 6,11 completed
# Patch 6,12 completed
# Patch 6,13 completed
# Patch 6,14 completed
# Patch 7,0 completed
# Patch 7,1 completed
# Patch 7,2 completed
# Patch 7,3 completed
# Patch 7,4 completed
# Patch 7,5 completed
# Patch 7,6 completed
# Patch 7,7 completed
# Patch 7,8 completed
# Patch 7,9 completed
# Patch 7,10 completed
# Patch 7,11 completed
# Patch 7,12 completed
# Patch 7,13 completed
# Patch 7,14 completed
# Patch 8,0 completed
# Patch 8,1 completed
# Patch 8,2 completed
# Patch 8,3 completed
# Patch 8,4 completed
# Patch 8,5 completed
# Patch 8,6 completed
# Patch 8,7 completed
# Patch 8,8 completed
# Patch 8,9 completed
# Patch 8,10 completed
# Patch 8,11 completed
# Patch 8,12 completed
# Patch 8,13 completed
# Patch 8,14 completed
# Patch 9,0 completed
# Patch 9,1 completed
# Patch 9,2 completed
# Patch 9,3 completed
# Patch 9,4 completed
# Patch 9,5 completed
# Patch 9,6 completed
# Patch 9,7 completed
# Patch 9,8 completed
# Patch 9,9 completed
# Patch 9,10 completed
# Patch 9,11 completed
# Patch 9,12 completed
# Patch 9,13 completed
# Patch 9,14 completed
# Patch 10,0 completed
# Patch 10,1 completed
# Patch 10,2 completed
# Patch 10,3 completed
# Patch 10,4 completed
# Patch 10,5 completed
# Patch 10,6 completed
# Patch 10,7 completed
# Patch 10,8 completed
# Patch 10,9 completed
# Patch 10,10 completed
# Patch 10,11 completed
# Patch 10,12 completed
# Patch 10,13 completed
# Patch 10,14 completed
# 180
# Working on ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Dharmavaram_Elukuntla_2617200/GeoTiff2/Elukuntala_Ortho_H3.tif
# Output path: ../results/Dharmavaram_Dharmavaram_Elukuntla_2617200/Elukuntala_Ortho_H3/output_Elukuntala_Ortho_H3_palette_file.shp
# Patch 0,0 completed
# Patch 0,1 completed
# Patch 0,2 completed
# Patch 0,3 completed
# Patch 0,4 completed
# Patch 0,5 completed
# Patch 0,6 completed
# Patch 0,7 completed
# Patch 0,8 completed
# Patch 0,9 completed
# Patch 0,10 completed
# Patch 0,11 completed
# Patch 0,12 completed
# Patch 0,13 completed
# Patch 0,14 completed
# Patch 0,15 completed
# Patch 0,16 completed
# Patch 0,17 completed
# Patch 0,18 completed
# Patch 0,19 completed
# Patch 0,20 completed
# Patch 0,21 completed
# Patch 0,22 completed
# Patch 0,23 completed
# Patch 0,24 completed
# Patch 0,25 completed
# Patch 0,26 completed
# Patch 1,0 completed
# Patch 1,1 completed
# Patch 1,2 completed
# Patch 1,3 completed
# Patch 1,4 completed
# Patch 1,5 completed
# Patch 1,6 completed
# Patch 1,7 completed
# Patch 1,8 completed
# Patch 1,9 completed
# Patch 1,10 completed
# Patch 1,11 completed
# Patch 1,12 completed
# Patch 1,13 completed
# Patch 1,14 completed
# Patch 1,15 completed
# Patch 1,16 completed
# Patch 1,17 completed
# Patch 1,18 completed
# Patch 1,19 completed
# Patch 1,20 completed
# Patch 1,21 completed
# Patch 1,22 completed
# Patch 1,23 completed
# Patch 1,24 completed
# Patch 1,25 completed
# Patch 1,26 completed
# Patch 2,0 completed
# Patch 2,1 completed
# Patch 2,2 completed
# Patch 2,3 completed
# Patch 2,4 completed
# Patch 2,5 completed
# Patch 2,6 completed
# Patch 2,7 completed
# Patch 2,8 completed
# Patch 2,9 completed
# Patch 2,10 completed
# Patch 2,11 completed
# Patch 2,12 completed
# Patch 2,13 completed
# Patch 2,14 completed
# Patch 2,15 completed
# Patch 2,16 completed
# Patch 2,17 completed
# Patch 2,18 completed
# Patch 2,19 completed
# Patch 2,20 completed
# Patch 2,21 completed
# Patch 2,22 completed
# Patch 2,23 completed
# Patch 2,24 completed
# Patch 2,25 completed
# Patch 2,26 completed
# Patch 3,0 completed
# Patch 3,1 completed
# Patch 3,2 completed
# Patch 3,3 completed
# Patch 3,4 completed
# Patch 3,5 completed
# Patch 3,6 completed
# Patch 3,7 completed
# Patch 3,8 completed
# Patch 3,9 completed
# Patch 3,10 completed
# Patch 3,11 completed
# Patch 3,12 completed
# Patch 3,13 completed
# Patch 3,14 completed
# Patch 3,15 completed
# Patch 3,16 completed
# Patch 3,17 completed
# Patch 3,18 completed
# Patch 3,19 completed
# Patch 3,20 completed
# Patch 3,21 completed
# Patch 3,22 completed
# Patch 3,23 completed
# Patch 3,24 completed
# Patch 3,25 completed
# Patch 3,26 completed
# Patch 4,0 completed
# Patch 4,1 completed
# Patch 4,2 completed
# Patch 4,3 completed
# Patch 4,4 completed
# Patch 4,5 completed
# Patch 4,6 completed
# Patch 4,7 completed
# Patch 4,8 completed
# Patch 4,9 completed
# Patch 4,10 completed
# Patch 4,11 completed
# Patch 4,12 completed
# Patch 4,13 completed
# Patch 4,14 completed
# Patch 4,15 completed
# Patch 4,16 completed
# Patch 4,17 completed
# Patch 4,18 completed
# Patch 4,19 completed
# Patch 4,20 completed
# Patch 4,21 completed
# Patch 4,22 completed
# Patch 4,23 completed
# Patch 4,24 completed
# Patch 4,25 completed
# Patch 4,26 completed
# Patch 5,0 completed
# Patch 5,1 completed
# Patch 5,2 completed
# Patch 5,3 completed
# Patch 5,4 completed
# Patch 5,5 completed
# Patch 5,6 completed
# Patch 5,7 completed
# Patch 5,8 completed
# Patch 5,9 completed
# Patch 5,10 completed
# Patch 5,11 completed
# Patch 5,12 completed
# Patch 5,13 completed
# Patch 5,14 completed
# Patch 5,15 completed
# Patch 5,16 completed
# Patch 5,17 completed
# Patch 5,18 completed
# Patch 5,19 completed
# Patch 5,20 completed
# Patch 5,21 completed
# Patch 5,22 completed
# Patch 5,23 completed
# Patch 5,24 completed
# Patch 5,25 completed
# Patch 5,26 completed
# Patch 6,0 completed
# Patch 6,1 completed
# Patch 6,2 completed
# Patch 6,3 completed
# Patch 6,4 completed
# Patch 6,5 completed
# Patch 6,6 completed
# Patch 6,7 completed
# Patch 6,8 completed
# Patch 6,9 completed
# Patch 6,10 completed
# Patch 6,11 completed
# Patch 6,12 completed
# Patch 6,13 completed
# Patch 6,14 completed
# Patch 6,15 completed
# Patch 6,16 completed
# Patch 6,17 completed
# Patch 6,18 completed
# Patch 6,19 completed
# Patch 6,20 completed
# Patch 6,21 completed
# Patch 6,22 completed
# Patch 6,23 completed
# Patch 6,24 completed
# Patch 6,25 completed
# Patch 6,26 completed
# Patch 7,0 completed
# Patch 7,1 completed
# Patch 7,2 completed
# Patch 7,3 completed
# Patch 7,4 completed
# Patch 7,5 completed
# Patch 7,6 completed
# Patch 7,7 completed
# Patch 7,8 completed
# Patch 7,9 completed
# Patch 7,10 completed
# Patch 7,11 completed
# Patch 7,12 completed
# Patch 7,13 completed
# Patch 7,14 completed
# Patch 7,15 completed
# Patch 7,16 completed
# Patch 7,17 completed
# Patch 7,18 completed
# Patch 7,19 completed
# Patch 7,20 completed
# Patch 7,21 completed
# Patch 7,22 completed
# Patch 7,23 completed
# Patch 7,24 completed
# Patch 7,25 completed
# Patch 7,26 completed
# Patch 8,0 completed
# Patch 8,1 completed
# Patch 8,2 completed
# Patch 8,3 completed
# Patch 8,4 completed
# Patch 8,5 completed
# Patch 8,6 completed
# Patch 8,7 completed
# Patch 8,8 completed
# Patch 8,9 completed
# Patch 8,10 completed
# Patch 8,11 completed
# Patch 8,12 completed
# Patch 8,13 completed
# Patch 8,14 completed
# Patch 8,15 completed
# Patch 8,16 completed
# Patch 8,17 completed
# Patch 8,18 completed
# Patch 8,19 completed
# Patch 8,20 completed
# Patch 8,21 completed
# Patch 8,22 completed
# Patch 8,23 completed
# Patch 8,24 completed
# Patch 8,25 completed
# Patch 8,26 completed
# Patch 9,0 completed
# Patch 9,1 completed
# Patch 9,2 completed
# Patch 9,3 completed
# Patch 9,4 completed
# Patch 9,5 completed
# Patch 9,6 completed
# Patch 9,7 completed
# Patch 9,8 completed
# Patch 9,9 completed
# Patch 9,10 completed
# Patch 9,11 completed
# Patch 9,12 completed
# Patch 9,13 completed
# Patch 9,14 completed
# Patch 9,15 completed
# Patch 9,16 completed
# Patch 9,17 completed
# Patch 9,18 completed
# Patch 9,19 completed
# Patch 9,20 completed
# Patch 9,21 completed
# Patch 9,22 completed
# Patch 9,23 completed
# Patch 9,24 completed
# Patch 9,25 completed
# Patch 9,26 completed
# Patch 10,0 completed
# Patch 10,1 completed
# Patch 10,2 completed
# Patch 10,3 completed
# Patch 10,4 completed
# Patch 10,5 completed
# Patch 10,6 completed
# Patch 10,7 completed
# Patch 10,8 completed
# Patch 10,9 completed
# Patch 10,10 completed
# Patch 10,11 completed
# Patch 10,12 completed
# Patch 10,13 completed
# Patch 10,14 completed
# Patch 10,15 completed
# Patch 10,16 completed
# Patch 10,17 completed
# Patch 10,18 completed
# Patch 10,19 completed
# Patch 10,20 completed
# Patch 10,21 completed
# Patch 10,22 completed
# Patch 10,23 completed
# Patch 10,24 completed
# Patch 10,25 completed
# Patch 10,26 completed
# Patch 11,0 completed
# Patch 11,1 completed
# Patch 11,2 completed
# Patch 11,3 completed
# Patch 11,4 completed
# Patch 11,5 completed
# Patch 11,6 completed
# Patch 11,7 completed
# Patch 11,8 completed
# Patch 11,9 completed
# Patch 11,10 completed
# Patch 11,11 completed
# Patch 11,12 completed
# Patch 11,13 completed
# Patch 11,14 completed
# Patch 11,15 completed
# Patch 11,16 completed
# Patch 11,17 completed
# Patch 11,18 completed
# Patch 11,19 completed
# Patch 11,20 completed
# Patch 11,21 completed
# Patch 11,22 completed
# Patch 11,23 completed
# Patch 11,24 completed
# Patch 11,25 completed
# Patch 11,26 completed
# Patch 12,0 completed
# Patch 12,1 completed
# Patch 12,2 completed
# Patch 12,3 completed
# Patch 12,4 completed
# Patch 12,5 completed
# Patch 12,6 completed
# Patch 12,7 completed
# Patch 12,8 completed
# Patch 12,9 completed
# Patch 12,10 completed
# Patch 12,11 completed
# Patch 12,12 completed
# Patch 12,13 completed
# Patch 12,14 completed
# Patch 12,15 completed
# Patch 12,16 completed
# Patch 12,17 completed
# Patch 12,18 completed
# Patch 12,19 completed
# Patch 12,20 completed
# Patch 12,21 completed
# Patch 12,22 completed
# Patch 12,23 completed
# Patch 12,24 completed
# Patch 12,25 completed
# Patch 12,26 completed
# Patch 13,0 completed
# Patch 13,1 completed
# Patch 13,2 completed
# Patch 13,3 completed
# Patch 13,4 completed
# Patch 13,5 completed
# Patch 13,6 completed
# Patch 13,7 completed
# Patch 13,8 completed
# Patch 13,9 completed
# Patch 13,10 completed
# Patch 13,11 completed
# Patch 13,12 completed
# Patch 13,13 completed
# Patch 13,14 completed
# Patch 13,15 completed
# Patch 13,16 completed
# Patch 13,17 completed
# Patch 13,18 completed
# Patch 13,19 completed
# Patch 13,20 completed
# Patch 13,21 completed
# Patch 13,22 completed
# Patch 13,23 completed
# Patch 13,24 completed
# Patch 13,25 completed
# Patch 13,26 completed
# Patch 14,0 completed
# Patch 14,1 completed
# Patch 14,2 completed
# Patch 14,3 completed
# Patch 14,4 completed
# Patch 14,5 completed
# Patch 14,6 completed
# Patch 14,7 completed
# Patch 14,8 completed
# Patch 14,9 completed
# Patch 14,10 completed
# Patch 14,11 completed
# Patch 14,12 completed
# Patch 14,13 completed
# Patch 14,14 completed
# Patch 14,15 completed
# Patch 14,16 completed
# Patch 14,17 completed
# Patch 14,18 completed
# Patch 14,19 completed
# Patch 14,20 completed
# Patch 14,21 completed
# Patch 14,22 completed
# Patch 14,23 completed
# Patch 14,24 completed
# Patch 14,25 completed
# Patch 14,26 completed
# 540
# Working on ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Ramagiri_Polepalli_2633400/GeoTiff2/Polepalli_Ortho_H2.tif
# Output path: ../results/Dharmavaram_Ramagiri_Polepalli_2633400/Polepalli_Ortho_H2/output_Polepalli_Ortho_H2_palette_file.shp
# Patch 0,0 completed
# Patch 0,1 completed
# Patch 0,2 completed
# Patch 0,3 completed
# Patch 0,4 completed
# Patch 0,5 completed
# Patch 0,6 completed
# Patch 0,7 completed
# Patch 0,8 completed
# Patch 0,9 completed
# Patch 0,10 completed
# Patch 0,11 completed
# Patch 0,12 completed
# Patch 0,13 completed
# Patch 0,14 completed
# Patch 0,15 completed
# Patch 0,16 completed
# Patch 0,17 completed
# Patch 0,18 completed
# Patch 0,19 completed
# Patch 0,20 completed
# Patch 0,21 completed
# Patch 0,22 completed
# Patch 0,23 completed
# Patch 0,24 completed
# Patch 0,25 completed
# Patch 0,26 completed
# Patch 0,27 completed
# Patch 0,28 completed
# Patch 0,29 completed
# Patch 0,30 completed
# Patch 0,31 completed
# Patch 0,32 completed
# Patch 0,33 completed
# Patch 0,34 completed
# Patch 1,0 completed
# Patch 1,1 completed
# Patch 1,2 completed
# Patch 1,3 completed
# Patch 1,4 completed
# Patch 1,5 completed
# Patch 1,6 completed
# Patch 1,7 completed
# Patch 1,8 completed
# Patch 1,9 completed
# Patch 1,10 completed
# Patch 1,11 completed
# Patch 1,12 completed
# Patch 1,13 completed
# Patch 1,14 completed
# Patch 1,15 completed
# Patch 1,16 completed
# Patch 1,17 completed
# Patch 1,18 completed
# Patch 1,19 completed
# Patch 1,20 completed
# Patch 1,21 completed
# Patch 1,22 completed
# Patch 1,23 completed
# Patch 1,24 completed
# Patch 1,25 completed
# Patch 1,26 completed
# Patch 1,27 completed
# Patch 1,28 completed
# Patch 1,29 completed
# Patch 1,30 completed
# Patch 1,31 completed
# Patch 1,32 completed
# Patch 1,33 completed
# Patch 1,34 completed
# Patch 2,0 completed
# Patch 2,1 completed
# Patch 2,2 completed
# Patch 2,3 completed
# Patch 2,4 completed
# Patch 2,5 completed
# Patch 2,6 completed
# Patch 2,7 completed
# Patch 2,8 completed
# Patch 2,9 completed
# Patch 2,10 completed
# Patch 2,11 completed
# Patch 2,12 completed
# Patch 2,13 completed
# Patch 2,14 completed
# Patch 2,15 completed
# Patch 2,16 completed
# Patch 2,17 completed
# Patch 2,18 completed
# Patch 2,19 completed
# Patch 2,20 completed
# Patch 2,21 completed
# Patch 2,22 completed
# Patch 2,23 completed
# Patch 2,24 completed
# Patch 2,25 completed
# Patch 2,26 completed
# Patch 2,27 completed
# Patch 2,28 completed
# Patch 2,29 completed
# Patch 2,30 completed
# Patch 2,31 completed
# Patch 2,32 completed
# Patch 2,33 completed
# Patch 2,34 completed
# Patch 3,0 completed
# Patch 3,1 completed
# Patch 3,2 completed
# Patch 3,3 completed
# Patch 3,4 completed
# Patch 3,5 completed
# Patch 3,6 completed
# Patch 6,32 completed
# Patch 6,33 completed
# Patch 6,34 completed
# Patch 7,0 completed
# Patch 7,1 completed
# Patch 7,2 completed
# Patch 7,3 completed
# Patch 7,4 completed
# Patch 7,5 completed
# Patch 7,6 completed
# Patch 7,7 completed
# Patch 7,8 completed
# Patch 7,9 completed
# Patch 7,10 completed
# Patch 7,11 completed
# Patch 7,12 completed
# Patch 7,13 completed
# Patch 7,14 completed
# Patch 7,15 completed
# Patch 7,16 completed
# Patch 7,17 completed
# Patch 7,18 completed
# Patch 7,19 completed
# Patch 7,20 completed
# Patch 7,21 completed
# Patch 7,22 completed
# Patch 7,23 completed
# Patch 7,24 completed
# Patch 7,25 completed
# Patch 7,26 completed
# Patch 7,27 completed
# Patch 7,28 completed
# Patch 7,29 completed
# Patch 7,30 completed
# Patch 7,31 completed
# Patch 7,32 completed
# Patch 7,33 completed
# Patch 7,34 completed
# Patch 8,0 completed
# Patch 8,1 completed
# Patch 8,2 completed
# Patch 8,3 completed
# Patch 8,4 completed
# Patch 8,5 completed
# Patch 8,6 completed
# Patch 8,7 completed
# Patch 8,8 completed
# Patch 8,9 completed
# Patch 8,10 completed
# Patch 8,11 completed
# Patch 8,12 completed
# Patch 8,13 completed
# Patch 8,14 completed
# Patch 8,15 completed
# Patch 8,16 completed
# Patch 8,17 completed
# Patch 8,18 completed
# Patch 8,19 completed
# Patch 8,20 completed
# Patch 8,21 completed
# Patch 8,22 completed
# Patch 8,23 completed
# Patch 8,24 completed
# Patch 8,25 completed
# Patch 8,26 completed
# Patch 8,27 completed
# Patch 8,28 completed
# Patch 8,29 completed
# Patch 8,30 completed
# Patch 8,31 completed
# Patch 8,32 completed
# Patch 8,33 completed
# Patch 8,34 completed
# Patch 9,0 completed
# Patch 9,1 completed
# Patch 9,2 completed
# Patch 9,3 completed
# Patch 9,4 completed
# Patch 9,5 completed
# Patch 9,6 completed
# Patch 9,7 completed
# Patch 9,8 completed
# Patch 9,9 completed
# Patch 9,10 completed
# Patch 9,11 completed
# Patch 9,12 completed
# Patch 9,13 completed
# Patch 9,14 completed
# Patch 9,15 completed
# Patch 9,16 completed
# Patch 9,17 completed
# Patch 9,18 completed
# Patch 9,19 completed
# Patch 9,20 completed
# Patch 9,21 completed
# Patch 9,22 completed
# Patch 9,23 completed
# Patch 9,24 completed
# Patch 9,25 completed
# Patch 9,26 completed
# Patch 9,27 completed
# Patch 9,28 completed
# Patch 9,29 completed
# Patch 9,30 completed
# Patch 9,31 completed
# Patch 9,32 completed
# Patch 9,33 completed
# Patch 9,34 completed
# Patch 10,0 completed
# Patch 10,1 completed
# Patch 10,2 completed
# Patch 10,3 completed
# Patch 10,4 completed
# Patch 10,5 completed
# Patch 10,6 completed
# Patch 10,7 completed
# Patch 10,8 completed
# Patch 10,9 completed
# Patch 10,10 completed
# Patch 10,11 completed
# Patch 10,12 completed
# Patch 10,13 completed
# Patch 10,14 completed
# Patch 10,15 completed
# Patch 10,16 completed
# Patch 10,17 completed
# Patch 10,18 completed
# Patch 10,19 completed
# Patch 10,20 completed
# Patch 10,21 completed
# Patch 10,22 completed
# Patch 10,23 completed
# Patch 10,24 completed
# Patch 10,25 completed
# Patch 10,26 completed
# Patch 10,27 completed
# Patch 10,28 completed
# Patch 10,29 completed
# Patch 10,30 completed
# Patch 10,31 completed
# Patch 10,32 completed
# Patch 10,33 completed
# Patch 10,34 completed
# Patch 11,0 completed
# Patch 11,1 completed
# Patch 11,2 completed
# Patch 11,3 completed
# Patch 11,4 completed
# Patch 11,5 completed
# Patch 11,6 completed
# Patch 11,7 completed
# Patch 11,8 completed
# Patch 11,9 completed
# Patch 11,10 completed
# Patch 11,11 completed
# Patch 11,12 completed
# Patch 11,13 completed
# Patch 11,14 completed
# Patch 11,15 completed
# Patch 11,16 completed
# Patch 11,17 completed
# Patch 11,18 completed
# Patch 11,19 completed
# Patch 11,20 completed
# Patch 11,21 completed
# Patch 11,22 completed
# Patch 11,23 completed
# Patch 11,24 completed
# Patch 11,25 completed
# Patch 11,26 completed
# Patch 11,27 completed
# Patch 11,28 completed
# Patch 11,29 completed
# Patch 11,30 completed
# Patch 11,31 completed
# Patch 11,32 completed
# Patch 11,33 completed
# Patch 11,34 completed
# Patch 12,0 completed
# Patch 12,1 completed
# Patch 12,2 completed
# Patch 12,3 completed
# Patch 12,4 completed
# Patch 12,5 completed
# Patch 12,6 completed
# Patch 12,7 completed
# Patch 12,8 completed
# Patch 12,9 completed
# Patch 12,10 completed
# Patch 12,11 completed
# Patch 12,12 completed
# Patch 12,13 completed
# Patch 12,14 completed
# Patch 12,15 completed
# Patch 12,16 completed
# Patch 12,17 completed
# Patch 12,18 completed
# Patch 12,19 completed
# Patch 12,20 completed
# Patch 12,21 completed
# Patch 12,22 completed
# Patch 12,23 completed
# Patch 12,24 completed
# Patch 12,25 completed
# Patch 12,26 completed
# Patch 12,27 completed
# Patch 12,28 completed
# Patch 12,29 completed
# Patch 12,30 completed
# Patch 12,31 completed
# Patch 12,32 completed
# Patch 12,33 completed
# Patch 12,34 completed
# Patch 13,0 completed
# Patch 13,1 completed
# Patch 13,2 completed
# Patch 13,3 completed
# Patch 13,4 completed
# Patch 13,5 completed
# Patch 13,6 completed
# Patch 13,7 completed
# Patch 13,8 completed
# Patch 13,9 completed
# Patch 13,10 completed
# Patch 13,11 completed
# Patch 13,12 completed
# Patch 13,13 completed
# Patch 13,14 completed
# Patch 13,15 completed
# Patch 13,16 completed
# Patch 13,17 completed
# Patch 13,18 completed
# Patch 13,19 completed
# Patch 13,20 completed
# Patch 13,21 completed
# Patch 13,22 completed
# Patch 13,23 completed
# Patch 13,24 completed
# Patch 13,25 completed
# Patch 13,26 completed
# Patch 13,27 completed
# Patch 13,28 completed
# Patch 13,29 completed
# Patch 13,30 completed
# Patch 13,31 completed
# Patch 13,32 completed
# Patch 13,33 completed
# Patch 13,34 completed
# Patch 14,0 completed
# Patch 14,1 completed
# Patch 14,2 completed
# Patch 14,3 completed
# Patch 14,4 completed
# Patch 14,5 completed
# Patch 14,6 completed
# Patch 14,7 completed
# Patch 14,8 completed
# Patch 14,9 completed
# Patch 14,10 completed
# Patch 29,5 completed
# Patch 29,6 completed
# Patch 29,7 completed
# Patch 29,8 completed
# Patch 29,9 completed
# Patch 29,10 completed
# Patch 29,11 completed
# Patch 29,12 completed
# Patch 29,13 completed
# Patch 29,14 completed
# Patch 29,15 completed
# Patch 29,16 completed
# Patch 29,17 completed
# Patch 29,18 completed
# Patch 29,19 completed
# Patch 29,20 completed
# Patch 29,21 completed
# Patch 29,22 completed
# Patch 29,23 completed
# Patch 29,24 completed
# Patch 29,25 completed
# Patch 29,26 completed
# Patch 29,27 completed
# Patch 29,28 completed
# Patch 29,29 completed
# Patch 29,30 completed
# Patch 29,31 completed
# Patch 29,32 completed
# Patch 29,33 completed
# Patch 29,34 completed
# Patch 30,0 completed
# Patch 30,1 completed
# Patch 30,2 completed
# Patch 30,3 completed
# Patch 30,4 completed
# Patch 30,5 completed
# Patch 30,6 completed
# Patch 30,7 completed
# Patch 30,8 completed
# Patch 30,9 completed
# Patch 30,10 completed
# Patch 30,11 completed
# Patch 30,12 completed
# Patch 30,13 completed
# Patch 30,14 completed
# Patch 30,15 completed
# Patch 30,16 completed
# Patch 30,17 completed
# Patch 30,18 completed
# Patch 30,19 completed
# Patch 30,20 completed
# Patch 30,21 completed
# Patch 30,22 completed
# Patch 30,23 completed
# Patch 30,24 completed
# Patch 30,25 completed
# Patch 30,26 completed
# Patch 30,27 completed
# Patch 30,28 completed
# Patch 30,29 completed
# Patch 30,30 completed
# Patch 30,31 completed
# Patch 30,32 completed
# Patch 30,33 completed
# Patch 30,34 completed
# 743
# Working on ../Dataset/Orthos_DSMs_Shapefiles/Dharmavaram_Ramagiri_Polepalli_2633400/GeoTiff2/Polepalli_Ortho_H1.tif
# Output path: ../results/Dharmavaram_Ramagiri_Polepalli_2633400/Polepalli_Ortho_H1/output_Polepalli_Ortho_H1_palette_file.shp
# Patch 0,0 completed
# Patch 0,1 completed
# Patch 0,2 completed
# Patch 0,3 completed
# Patch 0,4 completed
# Patch 0,5 completed
# Patch 0,6 completed
# Patch 0,7 completed
# Patch 0,8 completed
# Patch 0,9 completed
# Patch 0,10 completed
# Patch 0,11 completed
# Patch 0,12 completed
# Patch 0,13 completed
# Patch 0,14 completed
# Patch 0,15 completed
# Patch 0,16 completed
# Patch 0,17 completed
# Patch 0,18 completed
# Patch 0,19 completed
# Patch 0,20 completed
# Patch 0,21 completed
# Patch 0,22 completed
# Patch 1,0 completed
# Patch 1,1 completed
# Patch 1,2 completed
# Patch 1,3 completed
# Patch 1,4 completed
# Patch 1,5 completed
# Patch 1,6 completed
# Patch 1,7 completed
# Patch 1,8 completed
# Patch 1,9 completed
# Patch 1,10 completed
# Patch 1,11 completed
# Patch 1,12 completed
# Patch 1,13 completed
# Patch 1,14 completed
# Patch 1,15 completed
# Patch 1,16 completed
# Patch 1,17 completed
# Patch 1,18 completed
# Patch 1,19 completed
# Patch 1,20 completed
# Patch 1,21 completed
# Patch 1,22 completed
# Patch 2,0 completed
# Patch 2,1 completed
# Patch 2,2 completed
# Patch 2,3 completed
# Patch 2,4 completed
# Patch 2,5 completed
# Patch 7,20 completed
# Patch 7,21 completed
# Patch 7,22 completed
# Patch 8,0 completed
# Patch 8,1 completed
# Patch 8,2 completed
# Patch 8,3 completed
# Patch 8,4 completed
# Patch 8,5 completed
# Patch 8,6 completed
# Patch 8,7 completed
# Patch 8,8 completed
# Patch 8,9 completed
# Patch 8,10 completed
# Patch 8,11 completed
# Patch 8,12 completed
# Patch 8,13 completed
# Patch 8,14 completed
# Patch 8,15 completed
# Patch 8,16 completed
# Patch 8,17 completed
# Patch 8,18 completed
# Patch 8,19 completed
# Patch 8,20 completed
# Patch 8,21 completed
# Patch 8,22 completed
# Patch 9,0 completed
# Patch 9,1 completed
# Patch 9,2 completed
# Patch 9,3 completed
# Patch 9,4 completed
# Patch 9,5 completed
# Patch 9,6 completed
# Patch 9,7 completed
# Patch 9,8 completed
# Patch 9,9 completed
# Patch 9,10 completed
# Patch 9,11 completed
# Patch 9,12 completed
# Patch 9,13 completed
# Patch 9,14 completed
# Patch 9,15 completed
# Patch 9,16 completed
# Patch 9,17 completed
# Patch 9,18 completed
# Patch 9,19 completed
# Patch 9,20 completed
# Patch 9,21 completed
# Patch 9,22 completed
# Patch 10,0 completed
# Patch 10,1 completed
# Patch 10,2 completed
# Patch 10,3 completed
# Patch 10,4 completed
# Patch 10,5 completed
# Patch 10,6 completed
# Patch 10,7 completed
# Patch 10,8 completed
# Patch 10,9 completed
# Patch 10,10 completed
# Patch 10,11 completed
# Patch 10,12 completed
# Patch 10,13 completed
# Patch 10,14 completed
# Patch 10,15 completed
# Patch 10,16 completed
# Patch 10,17 completed
# Patch 10,18 completed
# Patch 10,19 completed
# Patch 10,20 completed
# Patch 10,21 completed
# Patch 10,22 completed
# Patch 11,0 completed
# Patch 11,1 completed
# Patch 11,2 completed
# Patch 11,3 completed
# Patch 11,4 completed
# Patch 11,5 completed
# Patch 11,6 completed
# Patch 11,7 completed
# Patch 11,8 completed
# Patch 11,9 completed
# Patch 11,10 completed
# Patch 11,11 completed
# Patch 11,12 completed
# Patch 11,13 completed
# Patch 11,14 completed
# Patch 11,15 completed
# Patch 11,16 completed
# Patch 11,17 completed
# Patch 11,18 completed
# Patch 11,19 completed
# Patch 11,20 completed
# Patch 11,21 completed
# Patch 11,22 completed
# Patch 12,0 completed
# Patch 12,1 completed
# Patch 12,2 completed
# Patch 12,3 completed
# Patch 12,4 completed
# Patch 12,5 completed
# Patch 12,6 completed
# Patch 12,7 completed
# Patch 12,8 completed
# Patch 12,9 completed
# Patch 12,10 completed
# Patch 12,11 completed
# Patch 12,12 completed
# Patch 12,13 completed
# Patch 12,14 completed
# Patch 12,15 completed
# Patch 12,16 completed
# Patch 12,17 completed
# Patch 12,18 completed
# Patch 12,19 completed
# Patch 12,20 completed
# Patch 12,21 completed
# Patch 12,22 completed
# Patch 13,0 completed
# Patch 13,1 completed
# Patch 13,2 completed
# Patch 13,3 completed
# Patch 13,4 completed
# Patch 13,5 completed
# Patch 13,6 completed
# Patch 13,7 completed
# Patch 13,8 completed
# Patch 13,9 completed
# Patch 13,10 completed
# Patch 13,11 completed
# Patch 0,0 completed
# Patch 0,1 completed
# Patch 0,2 completed
# Patch 0,3 completed
# Patch 0,4 completed
# Patch 0,5 completed
# Patch 0,6 completed
# Patch 0,7 completed
# Patch 0,8 completed
# Patch 0,9 completed
# Patch 0,10 completed
# Patch 0,11 completed
# Patch 0,12 completed
# Patch 0,13 completed
# Patch 0,14 completed
# Patch 0,15 completed
# Patch 0,16 completed
# Patch 0,17 completed
# Patch 0,18 completed
# Patch 0,19 completed
# Patch 0,20 completed
# Patch 0,21 completed
# Patch 0,22 completed
# Patch 0,23 completed
# Patch 0,24 completed
# Patch 1,0 completed
# Patch 1,1 completed
# Patch 1,2 completed
# Patch 1,3 completed
# Patch 1,4 completed
# Patch 1,5 completed
# Patch 1,6 completed
# Patch 1,7 completed
# Patch 1,8 completed
# Patch 1,9 completed
# Patch 1,10 completed
# Patch 1,11 completed
# Patch 1,12 completed
# Patch 1,13 completed
# Patch 1,14 completed
# Patch 1,15 completed
# Patch 1,16 completed
# Patch 1,17 completed
# Patch 1,18 completed
# Patch 1,19 completed
# Patch 1,20 completed
# Patch 1,21 completed
# Patch 1,22 completed
# Patch 1,23 completed
# Patch 1,24 completed
# Patch 2,0 completed
# Patch 2,1 completed
# Patch 2,2 completed
# Patch 2,3 completed
# Patch 2,4 completed
# Patch 2,5 completed
# Patch 2,6 completed
# Patch 2,7 completed
# Patch 2,8 completed
# Patch 2,9 completed
# Patch 2,10 completed
# Patch 2,11 completed
# Patch 2,12 completed
# Patch 2,13 completed
# Patch 2,14 completed
# Patch 2,15 completed
# Patch 2,16 completed
# Patch 2,17 completed
# Patch 2,18 completed
# Patch 2,19 completed
# Patch 2,20 completed
# Patch 2,21 completed
# Patch 2,22 completed
# Patch 2,23 completed
# Patch 2,24 completed
# Patch 3,0 completed
# Patch 3,1 completed
# Patch 3,2 completed
# Patch 3,3 completed
# Patch 3,4 completed
# Patch 3,5 completed
# Patch 3,6 completed
# Patch 3,7 completed
# Patch 3,8 completed
# Patch 3,9 completed
# Patch 3,10 completed
# Patch 3,11 completed
# Patch 3,12 completed
# Patch 3,13 completed
# Patch 3,14 completed
# Patch 3,15 completed
# Patch 3,16 completed
# Patch 3,17 completed
# Patch 3,18 completed
# Patch 3,19 completed
# Patch 3,20 completed
# Patch 3,21 completed
# Patch 3,22 completed
# Patch 3,23 completed
# Patch 3,24 completed
# Patch 4,0 completed
# Patch 4,1 completed
# Patch 4,2 completed
# Patch 4,3 completed
# Patch 4,4 completed
# Patch 4,5 completed
# Patch 4,6 completed
# Patch 4,7 completed
# Patch 4,8 completed
# Patch 4,9 completed
# Patch 4,10 completed
# Patch 4,11 completed
# Patch 4,12 completed
# Patch 4,13 completed
# Patch 4,14 completed
# Patch 4,15 completed
# Patch 4,16 completed
# Patch 4,17 completed
# Patch 4,18 completed
# Patch 4,19 completed
# Patch 4,20 completed
# Patch 4,21 completed
# Patch 4,22 completed
# Patch 4,23 completed
# Patch 4,24 completed
# Patch 5,0 completed
# Patch 5,1 completed
# Patch 5,2 completed
# Patch 5,3 completed
# Patch 5,4 completed
# Patch 5,5 completed
# Patch 5,6 completed
# Patch 5,7 completed
# Patch 5,8 completed
# Patch 5,9 completed
# Patch 5,10 completed
# Patch 5,11 completed
# Patch 5,12 completed
# Patch 5,13 completed
# Patch 5,14 completed
# Patch 5,15 completed
# Patch 5,16 completed
# Patch 5,17 completed
# Patch 5,18 completed
# Patch 5,19 completed
# Patch 5,20 completed
# Patch 5,21 completed
# Patch 5,22 completed
# Patch 5,23 completed
# Patch 5,24 completed
# Patch 6,0 completed
# Patch 6,1 completed
# Patch 6,2 completed
# Patch 6,3 completed
# Patch 6,4 completed
# Patch 6,5 completed
# Patch 6,6 completed
# Patch 6,7 completed
# Patch 6,8 completed
# Patch 6,9 completed
# Patch 6,10 completed
# Patch 6,11 completed
# Patch 6,12 completed
# Patch 6,13 completed
# Patch 6,14 completed
# Patch 6,15 completed
# Patch 6,16 completed
# Patch 6,17 completed
# Patch 6,18 completed
# Patch 6,19 completed
# Patch 6,20 completed
# Patch 6,21 completed
# Patch 6,22 completed
# Patch 6,23 completed
# Patch 6,24 completed
# Patch 7,0 completed
# Patch 7,1 completed
# Patch 7,2 completed
# Patch 7,3 completed
# Patch 7,4 completed
# Patch 7,5 completed
# Patch 7,6 completed
# Patch 7,7 completed
# Patch 7,8 completed
# Patch 7,9 completed
# Patch 7,10 completed
# Patch 7,11 completed
# Patch 7,12 completed
# Patch 7,13 completed
# Patch 7,14 completed
# Patch 7,15 completed
# Patch 7,16 completed
# Patch 7,17 completed
# Patch 7,18 completed
# Patch 7,19 completed
# Patch 7,20 completed
# Patch 7,21 completed
# Patch 7,22 completed
# Patch 7,23 completed
# Patch 7,24 completed
# Patch 8,0 completed
# Patch 8,1 completed
# Patch 8,2 completed
# Patch 8,3 completed
# Patch 8,4 completed
# Patch 8,5 completed
# Patch 8,6 completed
# Patch 8,7 completed
# Patch 8,8 completed
# Patch 8,9 completed
# Patch 8,10 completed
# Patch 8,11 completed
# Patch 8,12 completed
# Patch 8,13 completed
# Patch 8,14 completed
# Patch 8,15 completed
# Patch 8,16 completed
# Patch 8,17 completed
# Patch 8,18 completed
# Patch 8,19 completed
# Patch 8,20 completed
# Patch 8,21 completed
# Patch 8,22 completed
# Patch 8,23 completed
# Patch 8,24 completed
# Patch 9,0 completed
# Patch 9,1 completed
# Patch 9,2 completed
# Patch 9,3 completed
# Patch 9,4 completed
# Patch 9,5 completed
# Patch 9,6 completed
# Patch 9,7 completed
# Patch 9,8 completed
# Patch 9,9 completed
# Patch 9,10 completed
# Patch 9,11 completed
# Patch 9,12 completed
# Patch 9,13 completed
# Patch 9,14 completed
# Patch 9,15 completed
# Patch 9,16 completed
# Patch 9,17 completed
# Patch 9,18 completed
# Patch 9,19 completed
# Patch 9,20 completed
# Patch 9,21 completed
# Patch 9,22 completed
# Patch 9,23 completed
# Patch 9,24 completed
# Patch 10,0 completed
# Patch 10,1 completed
# Patch 10,2 completed
# Patch 10,3 completed
# Patch 10,4 completed
# Patch 10,5 completed
# Patch 10,6 completed
# Patch 10,7 completed
# Patch 10,8 completed
# Patch 10,9 completed
# Patch 10,10 completed
# Patch 10,11 completed
# Patch 10,12 completed
# Patch 10,13 completed
# Patch 10,14 completed
# Patch 10,15 completed
# Patch 10,16 completed
# Patch 10,17 completed
# Patch 10,18 completed
# Patch 10,19 completed
# Patch 10,20 completed
# Patch 10,21 completed
# Patch 10,22 completed
# Patch 10,23 completed
# Patch 10,24 completed
# Patch 11,0 completed
# Patch 11,1 completed
# Patch 11,2 completed
# Patch 11,3 completed
# Patch 11,4 completed
# Patch 11,5 completed
# Patch 11,6 completed
# Patch 11,7 completed
# Patch 11,8 completed
# Patch 11,9 completed
# Patch 11,10 completed
# Patch 11,11 completed
# Patch 11,12 completed
# Patch 11,13 completed
# Patch 11,14 completed
# Patch 11,15 completed
# Patch 11,16 completed
# Patch 11,17 completed
# Patch 11,18 completed
# Patch 11,19 completed
# Patch 11,20 completed
# Patch 11,21 completed
# Patch 11,22 completed
# Patch 11,23 completed
# Patch 11,24 completed
# Patch 12,0 completed
# Patch 12,1 completed
# Patch 12,2 completed
# Patch 12,3 completed
# Patch 12,4 completed
# Patch 12,5 completed
# Patch 12,6 completed
# Patch 12,7 completed
# Patch 12,8 completed
# Patch 12,9 completed
# Patch 12,10 completed
# Patch 12,11 completed
# Patch 12,12 completed
# Patch 12,13 completed
# Patch 12,14 completed
# Patch 12,15 completed
# Patch 12,16 completed
# Patch 12,17 completed
# Patch 12,18 completed
# Patch 12,19 completed
# Patch 12,20 completed
# Patch 12,21 completed
# Patch 12,22 completed
# Patch 12,23 completed
# Patch 12,24 completed
# Patch 13,0 completed
# Patch 13,1 completed
# Patch 13,2 completed
# Patch 13,3 completed
# Patch 13,4 completed
# Patch 13,5 completed
# Patch 13,6 completed
# Patch 13,7 completed
# Patch 13,8 completed
# Patch 13,9 completed
# Patch 13,10 completed
# Patch 13,11 completed
# Patch 13,12 completed
# Patch 13,13 completed
# Patch 13,14 completed
# Patch 13,15 completed
# Patch 13,16 completed
# Patch 13,17 completed
# Patch 13,18 completed
# Patch 13,19 completed
# Patch 13,20 completed
# Patch 13,21 completed
# Patch 13,22 completed
# Patch 13,23 completed
# Patch 13,24 completed
# Patch 14,0 completed
# Patch 14,1 completed
# Patch 14,2 completed
# Patch 14,3 completed
# Patch 14,4 completed
# Patch 14,5 completed
# Patch 14,6 completed
# Patch 14,7 completed
# Patch 14,8 completed
# Patch 14,9 completed
# Patch 14,10 completed
# Patch 14,11 completed
# Patch 14,12 completed
# Patch 14,13 completed
# Patch 14,14 completed
# Patch 14,15 completed
# Patch 14,16 completed
# Patch 14,17 completed
# Patch 14,18 completed
# Patch 14,19 completed
# Patch 14,20 completed
# Patch 14,21 completed
# Patch 14,22 completed
# Patch 14,23 completed
# Patch 14,24 completed
# Patch 15,0 completed
# Patch 15,1 completed
# Patch 15,2 completed
# Patch 15,3 completed
# Patch 15,4 completed
# Patch 15,5 completed
# Patch 15,6 completed
# Patch 15,7 completed
# Patch 15,8 completed
# Patch 15,9 completed
# Patch 15,10 completed
# Patch 20,15 completed
# Patch 20,16 completed
# Patch 20,17 completed
# Patch 20,18 completed
# Patch 20,19 completed
# Patch 20,20 completed
# Patch 20,21 completed
# Patch 20,22 completed
# Patch 20,23 completed
# Patch 20,24 completed
# 261
# Working on ../Dataset/Orthos_DSMs_Shapefiles/Kadiri_Talupula_Lakkasamudram_02622300/GeoTiff2/Lakkasamudram_Ortho_H7.tif
# Output path: ../results/Kadiri_Talupula_Lakkasamudram_02622300/Lakkasamudram_Ortho_H7/output_Lakkasamudram_Ortho_H7_palette_file.shp
# Patch 0,0 completed
# Patch 0,1 completed
# Patch 0,2 completed
# Patch 0,3 completed
# Patch 0,4 completed
# Patch 0,5 completed
# Patch 0,6 completed
# Patch 0,7 completed
# Patch 0,8 completed
# Patch 0,9 completed
# Patch 0,10 completed
# Patch 0,11 completed
# Patch 0,12 completed
# Patch 0,13 completed
# Patch 0,14 completed
# Patch 1,0 completed
# Patch 1,1 completed
# Patch 1,2 completed
# Patch 1,3 completed
# Patch 1,4 completed
# Patch 1,5 completed
# Patch 1,6 completed
# Patch 1,7 completed
# Patch 1,8 completed
# Patch 1,9 completed
# Patch 1,10 completed
# Patch 1,11 completed
# Patch 1,12 completed
# Patch 1,13 completed
# Patch 1,14 completed
# Patch 2,0 completed
# Patch 2,1 completed
# Patch 2,2 completed
# Patch 2,3 completed
# Patch 2,4 completed
# Patch 2,5 completed
# Patch 2,6 completed
# Patch 2,7 completed
# Patch 2,8 completed
# Patch 2,9 completed
# Patch 2,10 completed
# Patch 2,11 completed
# Patch 2,12 completed
# Patch 2,13 completed
# Patch 2,14 completed
# Patch 3,0 completed
# Patch 3,1 completed
# Patch 3,2 completed
# Patch 3,3 completed
# Patch 3,4 completed
# Patch 3,5 completed
# Patch 3,6 completed
# Patch 3,7 completed
# Patch 3,8 completed
# Patch 3,9 completed
# Patch 3,10 completed
# Patch 3,11 completed
# Patch 3,12 completed
# Patch 3,13 completed
# Patch 3,14 completed
# Patch 4,0 completed
# Patch 4,1 completed
# Patch 4,2 completed
# Patch 4,3 completed
# Patch 4,4 completed
# Patch 4,5 completed
# Patch 4,6 completed
# Patch 4,7 completed
# Patch 4,8 completed
# Patch 4,9 completed
# Patch 4,10 completed
# Patch 4,11 completed
# Patch 4,12 completed
# Patch 4,13 completed
# Patch 4,14 completed
# Patch 5,0 completed
# Patch 5,1 completed
# Patch 5,2 completed
# Patch 5,3 completed
# Patch 5,4 completed
# Patch 5,5 completed
# Patch 5,6 completed
# Patch 5,7 completed
# Patch 5,8 completed
# Patch 5,9 completed
# Patch 5,10 completed
# Patch 5,11 completed
# Patch 5,12 completed
# Patch 5,13 completed
# Patch 5,14 completed
# Patch 6,0 completed
# Patch 6,1 completed
# Patch 6,2 completed
# Patch 6,3 completed
# Patch 6,4 completed
# Patch 6,5 completed
# Patch 6,6 completed
# Patch 6,7 completed
# Patch 6,8 completed
# Patch 6,9 completed
# Patch 6,10 completed
# Patch 6,11 completed
# Patch 6,12 completed
# Patch 6,13 completed
# Patch 6,14 completed
# Patch 7,0 completed
# Patch 7,1 completed
# Patch 7,2 completed
# Patch 7,3 completed
# Patch 7,4 completed
# Patch 7,5 completed
# Patch 7,6 completed
# Patch 7,7 completed
# Patch 7,8 completed
# Patch 7,9 completed
# Patch 7,10 completed
# Patch 7,11 completed
# Patch 7,12 completed
# Patch 7,13 completed
# Patch 7,14 completed
# Patch 8,0 completed
# Patch 8,1 completed
# Patch 8,2 completed
# Patch 8,3 completed
# Patch 8,4 completed
# Patch 8,5 completed
# Patch 8,6 completed
# Patch 8,7 completed
# Patch 8,8 completed
# Patch 8,9 completed
# Patch 8,10 completed
# Patch 8,11 completed
# Patch 8,12 completed
# Patch 8,13 completed
# Patch 8,14 completed
# Patch 9,0 completed
# Patch 9,1 completed
# Patch 9,2 completed
# Patch 9,3 completed
# Patch 9,4 completed
# Patch 9,5 completed
# Patch 9,6 completed
# Patch 9,7 completed
# Patch 9,8 completed
# Patch 9,9 completed
# Patch 9,10 completed
# Patch 9,11 completed
# Patch 9,12 completed
# Patch 9,13 completed
# Patch 9,14 completed
# Patch 10,0 completed
# Patch 10,1 completed
# Patch 10,2 completed
# Patch 10,3 completed
# Patch 10,4 completed
# Patch 10,5 completed
# Patch 10,6 completed
# Patch 10,7 completed
# Patch 10,8 completed
# Patch 10,9 completed
# Patch 10,10 completed
# Patch 10,11 completed
# Patch 10,12 completed
# Patch 10,13 completed
# Patch 10,14 completed
# Patch 11,0 completed
# Patch 11,1 completed
# Patch 11,2 completed
# Patch 11,3 completed
# Patch 11,4 completed
# Patch 11,5 completed
# Patch 11,6 completed
# Patch 11,7 completed
# Patch 11,8 completed
# Patch 11,9 completed
# Patch 11,10 completed
# Patch 11,11 completed
# Patch 11,12 completed
# Patch 11,13 completed
# Patch 11,14 completed
# Patch 12,0 completed
# Patch 12,1 completed
# Patch 12,2 completed
# Patch 12,3 completed
# Patch 12,4 completed
# Patch 12,5 completed
# Patch 12,6 completed
# Patch 12,7 completed
# Patch 12,8 completed
# Patch 12,9 completed
# Patch 12,10 completed
# Patch 12,11 completed
# Patch 12,12 completed
# Patch 12,13 completed
# Patch 12,14 completed
# 110
# Working on ../Dataset/Orthos_DSMs_Shapefiles/Kadiri_Talupula_Lakkasamudram_02622300/GeoTiff2/Lakkasamudram_Ortho_H5.tif
# Output path: ../results/Kadiri_Talupula_Lakkasamudram_02622300/Lakkasamudram_Ortho_H5/output_Lakkasamudram_Ortho_H5_palette_file.shp

# %% [markdown]
# #### Run inference on single file

# %%
# overlap_threshold = 0.5  # Adjust this threshold as needed
# image_path = "../Dataset/test_files/Chowtakuntapalli_ORTHO_H1.tif"  # Path to your test image
# patch_size = (1024, 1024, 3)  # Adjust this to the desired patch size and channel count
# step = 512

# %%
# patches, padded_image = extract_patches(image_path, patch_size, step)
# print(f"Number of patches: {patches.shape[0] * patches.shape[1]}")
# print(f"Shape of a single patch: {patches[0, 0, 0].shape}")

# %%
# save_patches(patches, "../Dataset/patches")

# %%
# output_shp_path = "../shp_files/output_shp.shp"
# process_patches_with_overlap_adjustment(image_path, patches, model_inference, step, overlap_threshold, output_shp_path)
